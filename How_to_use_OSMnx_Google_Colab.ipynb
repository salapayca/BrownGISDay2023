# %% [markdown]
# # How to use OpenStreetMap in our Notebooks

# %% [markdown]
# In this tutorial, we will be using OSMnx to perform OSM tasks. We will start with setting it up.
#
# OSMnx is a Python package that lets you download spatial geometries and model project, visualize, and analize street network and other spatial data from OpenStreetMap's API.
# Since OSMnx is a package, we should start with installing it first. For Google Colab, packages are installed via pip (preferred installer program) command-line utility. The the following to your first cell:

# %%
# !pip install osmnx
# Out:
# Collecting osmnx
#   Downloading osmnx-1.7.1-py3-none-any.whl (102 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.4/102.4 kB 3.1 MB/s eta 0:00:00
# Requirement already satisfied: geopandas>=0.12 in /usr/local/lib/python3.10/dist-packages (from osmnx) (0.13.2)
# Requirement already satisfied: networkx>=2.5 in /usr/local/lib/python3.10/dist-packages (from osmnx) (3.2)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from osmnx) (1.23.5)
# Requirement already satisfied: pandas>=1.1 in /usr/local/lib/python3.10/dist-packages (from osmnx) (1.5.3)
# Requirement already satisfied: requests>=2.27 in /usr/local/lib/python3.10/dist-packages (from osmnx) (2.31.0)
# Requirement already satisfied: shapely>=2.0 in /usr/local/lib/python3.10/dist-packages (from osmnx) (2.0.2)
# Requirement already satisfied: fiona>=1.8.19 in /usr/local/lib/python3.10/dist-packages (from geopandas>=0.12->osmnx) (1.9.5)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from geopandas>=0.12->osmnx) (23.2)
# Requirement already satisfied: pyproj>=3.0.1 in /usr/local/lib/python3.10/dist-packages (from geopandas>=0.12->osmnx) (3.6.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1->osmnx) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1->osmnx) (2023.3.post1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.27->osmnx) (3.3.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.27->osmnx) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.27->osmnx) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.27->osmnx) (2023.7.22)
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas>=0.12->osmnx) (23.1.0)
# Requirement already satisfied: click~=8.0 in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas>=0.12->osmnx) (8.1.7)
# Requirement already satisfied: click-plugins>=1.0 in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas>=0.12->osmnx) (1.1.1)
# Requirement already satisfied: cligj>=0.5 in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas>=0.12->osmnx) (0.7.2)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas>=0.12->osmnx) (1.16.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas>=0.12->osmnx) (67.7.2)
# Installing collected packages: osmnx
# Successfully installed osmnx-1.7.1

# %%
import osmnx as ox

# %% [markdown]
# Here, you might wonder why we have ox? Sometimes, if we are going to use the functions available under a package, we need dot(.) notation to call those functions.And if this is going to be repeated multiple times, it is good to have a shorter acroynm so we don't have to type the full package name again and again. Other common examples are
# - importing pandas as pd,
# - importing numpy as np, and
# - importing matplotlib as plt.

# %% [markdown]
# ## ACQUIRE  THE DATASET

# %% [markdown]
# It is not visible yet but since we imported osmnx, now we can access entire world! Let's try! Let's create a variable place and select our favorite city:

# %%
place ='Manhattan, New York, USA'

# %% [markdown]
# Now, assume we would like to go to Manhattan and acquire some Point of Interests (POIs) as cafes. See whatelse you can choose as <a href="https://wiki.openstreetmap.org/wiki/Key:amenity">**"amenity"**</a>.
#
# Under OSMnx , there is a dictionary object called *geometries_from_place()* function and we can use call it as follows:

# %%
tags ={'amenity':'cafe'}
cafe=ox.geometries_from_place(place, tags=tags)

cafe.head()
# Out:
# <ipython-input-4-7467e91e0678>:2: UserWarning: The `geometries` module and `geometries_from_X` functions have been renamed the `features` module and `features_from_X` functions. Use these instead. The `geometries` module and function names are deprecated and will be removed in a future release.
#   cafe=ox.geometries_from_place(place, tags=tags)
# <frozen importlib._bootstrap>:914: ImportWarning: APICoreClientInfoImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _PyDrive2ImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _OpenCVImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _AltairImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: APICoreClientInfoImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _PyDrive2ImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _OpenCVImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _AltairImportHook.find_spec() not found; falling back to find_module()
#                        addr:housenumber addr:postcode      addr:street  \
# element_type osmid
# node         410235438              975         10025  Columbus Avenue
#              419367394              NaN           NaN              NaN
#              419367529              NaN           NaN              NaN
#              560636265              NaN           NaN              NaN
#              561239802              564         10016       3rd Avenue
#
#                        amenity             name                    geometry  \
# element_type osmid
# node         410235438    cafe     Zanny's Cafe  POINT (-73.96182 40.80037)
#              419367394    cafe        Perk Kafe  POINT (-73.97726 40.74771)
#              419367529    cafe     Lenox Coffee  POINT (-73.94318 40.81001)
#              560636265    cafe        Starbucks  POINT (-74.01413 40.70328)
#              561239802    cafe  Cafe Delecctica  POINT (-73.97663 40.74816)
#
#                                      cuisine drink:coffee drink:espresso  \
# element_type osmid
# node         410235438                   NaN          NaN            NaN
#              419367394           coffee_shop          yes            yes
#              419367529           coffee_shop          NaN            NaN
#              560636265           coffee_shop          NaN            NaN
#              561239802  coffee_shop;sandwich          yes            yes
#
#                        internet_access  ... roof:shape building:use max_level  \
# element_type osmid                      ...
# node         410235438             NaN  ...        NaN          NaN       NaN
#              419367394            wlan  ...        NaN          NaN       NaN
#              419367529            wlan  ...        NaN          NaN       NaN
#              560636265             NaN  ...        NaN          NaN       NaN
#              561239802             NaN  ...        NaN          NaN       NaN
#
#                        old_name roof:colour indoor surveillance fixme  \
# element_type osmid
# node         410235438      NaN         NaN    NaN          NaN   NaN
#              419367394      NaN         NaN    NaN          NaN   NaN
#              419367529      NaN         NaN    NaN          NaN   NaN
#              560636265      NaN         NaN    NaN          NaN   NaN
#              561239802      NaN         NaN    NaN          NaN   NaN
#
#                        contact:discord seasonal
# element_type osmid
# node         410235438             NaN      NaN
#              419367394             NaN      NaN
#              419367529             NaN      NaN
#              560636265             NaN      NaN
#              561239802             NaN      NaN
#
# [5 rows x 196 columns]

# %% [markdown]
# How we have our data points, let's see them on a map by using <a href="https://python-visualization.github.io/folium/"> Folium!

# %%
# !pip install folium
# Out:
# Requirement already satisfied: folium in /usr/local/lib/python3.10/dist-packages (0.14.0)
# Requirement already satisfied: branca>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from folium) (0.6.0)
# Requirement already satisfied: jinja2>=2.9 in /usr/local/lib/python3.10/dist-packages (from folium) (3.1.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from folium) (1.23.5)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from folium) (2.31.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2>=2.9->folium) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->folium) (3.3.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->folium) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->folium) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->folium) (2023.7.22)

# %%
import folium

# %%
cafe_points = cafe[cafe.geom_type =='Point'][:100]

# %% [markdown]
# First we need to create a Map object that we will use as a base map, then we need to use Marker function to visualize our points on that base map.

# %%
m = folium.Map([40.754932, -73.984016], zoom_start=10) #why do we specify the lat and long? Where do you think we will be zooming into?

# %% [markdown]
# What are the inputs for <a href="https://python-visualization.github.io/folium/quickstart.html#Markers">**folium.Marker()**</a> ?

# %% [markdown]
# OK. So we need to pass our locations to the ``` folium.Marker()``` as a parameter. We have the map, we have the geopandas which holds our points, but how our map will know where those points are located? Can you find by looking at the table? Which column(s) do we need to access? Which door do we have to knock (dot) ?

# %%
latitudes= cafe_points.geometry.x
longitudes = cafe_points.geometry.y

# %% [markdown]
# Finally, we can get the latitudes and longitudes. Now it is time to zip them up! Let's check <a href="https://www.w3schools.com/python/ref_func_zip.asp">this</a> first.

# %%
locs = zip(cafe_points.geometry.y, cafe_points.geometry.x)

names = cafe_points.name

for location,name in zip(locs,names):

    folium.Marker(location=location, popup=name).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6348e95ca8f254585cddab3356772f0a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6348e95ca8f254585cddab3356772f0a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6348e95ca8f254585cddab3356772f0a = L.map(
#                 &quot;map_6348e95ca8f254585cddab3356772f0a&quot;,
#                 {
#                     center: [40.754932, -73.984016],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_650534a27780a5ee0a0bd7797cdfc98a = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_6348e95ca8f254585cddab3356772f0a);
#
#
#             var marker_712b7734433ec0a88c0ec76353bdd3c0 = L.marker(
#                 [40.8003709, -73.961816],
#                 {}
#             ).addTo(map_6348e95ca8f254585cddab3356772f0a);
#
#
#         var popup_6d519f408d38ffb82dca7ca80c91cc90 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2e4ff7c9581def671caf6c9f622248b9 = $(`&lt;div id=&quot;html_2e4ff7c9581def671caf6c9f622248b9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Zanny&#x27;s Cafe&lt;/div&gt;`)[0];
#                 popup_6d519f408d38ffb82dca7ca80c91cc90.setContent(html_2e4ff7c9581def671caf6c9f622248b9);
#
#
#
#         marker_712b7734433ec0a88c0ec76353bdd3c0.bindPopup(popup_6d519f408d38ffb82dca7ca80c91cc90)
#         ;
#
#
#
#
#             var marker_c116fd56d5d37a4bb555a22e2deead21 = L.marker(
#                 [40.7477067, -73.9772631],
#                 {}
#             ).addTo(map_6348e95ca8f254585cddab3356772f0a);
#
#
#         var popup_033a5094f8bc74ab7c3bf77be522b6f8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2fe7a652bb3283a94e77c5cc85d32937 = $(`&lt;div id=&quot;html_2fe7a652bb3283a94e77c5cc85d32937&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Perk Kafe&lt;/div&gt;`)[0];
#                 popup_033a5094f8bc74ab7c3bf77be522b6f8.setContent(html_2fe7a652bb3283a94e77c5cc85d32937);
#
#
#
#         marker_c116fd56d5d37a4bb555a22e2deead21.bindPopup(popup_033a5094f8bc74ab7c3bf77be522b6f8)
#         ;
#
#
#
#
#             var marker_ac0a76d5f4ace86bb6cb25fb7524704e = L.marker(
#                 [40.810011, -73.9431823],
#                 {}
#             ).addTo(map_6348e95ca8f254585cddab3356772f0a);
#
#
#         var popup_863e31acc2819f90b2fdcd7f1cbc0ce7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_570041cf8913fcc234127a91627c6c4a = $(`&lt;div id=&quot;html_570041cf8913fcc234127a91627c6c4a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Lenox Coffee&lt;/div&gt;`)[0];
#                 popup_863e31acc2819f90b2fdcd7f1cbc0ce7.setContent(html_570041cf8913fcc234127a91627c6c4a);
#
#
#
#         marker_ac0a76d5f4ace86bb6cb25fb7524704e.bindPopup(popup_863e31acc2819f90b2fdcd7f1cbc0ce7)
#         ;
#
#
#
#
#             var marker_0afb1034f112a0007b4841d64bb168ff = L.marker(
#                 [40.7032771, -74.0141339],
#                 {}
#             ).addTo(map_6348e95ca8f254585cddab3356772f0a);
#
#
#         var popup_49597547ec168e9ad4874b792dafae0b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_dac987e19ddba421250fd349f9dc93d8 = $(`&lt;div id=&quot;html_dac987e19ddba421250fd349f9dc93d8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Starbucks&lt;/div&gt;`)[0];
#                 popup_49597547ec168e9ad4874b792dafae0b.setContent(html_dac987e19ddba421250fd349f9dc93d8);
#
#
#
#         marker_0afb1034f112a0007b4841d64bb168ff.bindPopup(popup_49597547ec168e9ad4874b792dafae0b)
#         ;
#
#
#
#
#             var marker_e6b3fbb0d1e093baf96005e449899fba = L.marker(
#                 [40.7481608, -73.9766252],
#                 {}
#             ).addTo(map_6348e95ca8f254585cddab3356772f0a);
#
#
#         var popup_83876934a7404d2b215d11dde11d3e8a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_661b3aa5df45efa1f93866ba2d32d37a = $(`&lt;div id=&quot;html_661b3aa5df45efa1f93866ba2d32d37a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Cafe Delecctica&lt;/div&gt;`)[0];
#                 popup_83876934a7404d2b215d11dde11d3e8a.setContent(html_661b3aa5df45efa1f93866ba2d32d37a);
#
#
#
#         marker_e6b3fbb0d1e093baf96005e449899fba.bindPopup(popup_83876934a7404d2b215d11dde11d3e8a)
#         ;
#
#
#
#
#             var marker_b72d72c19593983a35481e87aed372ea = L.marker(
#                 [40.7521865, -73.991068],

# %% [markdown]
# You can save your map as an html:

# %%
m.save('ny_cafes.html')

# %% [markdown]
# ## What about Museums? Can you get the museums?

# %% [markdown]
# **Hint** : You can check the <a href="https://wiki.openstreetmap.org/wiki/Map_features"> **link** </a> to see how we can get more tags.
#     Also, feel free to customize your map by checking <a href="https://python-visualization.github.io/folium/quickstart.html#Markers">**other markers**</a>.

# %%
tags={'tourism':'museum'}
museums=ox.geometries_from_place(place, tags=tags)
museums.head()
# Out:
# <ipython-input-12-b69527f25f42>:2: UserWarning: The `geometries` module and `geometries_from_X` functions have been renamed the `features` module and `features_from_X` functions. Use these instead. The `geometries` module and function names are deprecated and will be removed in a future release.
#   museums=ox.geometries_from_place(place, tags=tags)
#                        addr:city addr:floor addr:housenumber addr:postcode  \
# element_type osmid
# node         368052081  New York          2               54         10004
#              368061337  New York        NaN                1         10004
#              368061605       NaN        NaN              NaN           NaN
#              368061607       NaN        NaN              NaN           NaN
#              368061657       NaN        NaN              NaN           NaN
#
#                        addr:state    addr:street gnis:county_name  \
# element_type osmid
# node         368052081         NY   Pearl Street         New York
#              368061337         NY  Bowling Green              NaN
#              368061605         NY            NaN         New York
#              368061607         NY            NaN         New York
#              368061657         NY            NaN         New York
#
#                        gnis:feature_id                      gnis:import_uuid  \
# element_type osmid
# node         368052081         2057419  57871b70-0100-4405-bb30-88b2e001a944
#              368061337         2057415                                   NaN
#              368061605         2091590                                   NaN
#              368061607         2091587                                   NaN
#              368061657         2080645  57871b70-0100-4405-bb30-88b2e001a944
#
#                                                           name  ... layer  \
# element_type osmid                                              ...
# node         368052081                  Fraunces Tavern Museum  ...   NaN
#              368061337  National Museum of the American Indian  ...   NaN
#              368061605               Yeshiva University Museum  ...   NaN
#              368061607                    Dahesh Museum of Art  ...   NaN
#              368061657                   Museum of African Art  ...   NaN
#
#                        name:cs name:it name:nl name:pt area ways type name:hi  \
# element_type osmid
# node         368052081     NaN     NaN     NaN     NaN  NaN  NaN  NaN     NaN
#              368061337     NaN     NaN     NaN     NaN  NaN  NaN  NaN     NaN
#              368061605     NaN     NaN     NaN     NaN  NaN  NaN  NaN     NaN
#              368061607     NaN     NaN     NaN     NaN  NaN  NaN  NaN     NaN
#              368061657     NaN     NaN     NaN     NaN  NaN  NaN  NaN     NaN
#
#                        name:de
# element_type osmid
# node         368052081     NaN
#              368061337     NaN
#              368061605     NaN
#              368061607     NaN
#              368061657     NaN
#
# [5 rows x 131 columns]

# %%
museums_points = museums[museums.geom_type =='Point'][:100]

museums_points.head()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#                        addr:city addr:floor addr:housenumber addr:postcode  \
# element_type osmid
# node         368052081  New York          2               54         10004
#              368061337  New York        NaN                1         10004
#              368061605       NaN        NaN              NaN           NaN
#              368061607       NaN        NaN              NaN           NaN
#              368061657       NaN        NaN              NaN           NaN
#
#                        addr:state    addr:street gnis:county_name  \
# element_type osmid
# node         368052081         NY   Pearl Street         New York
#              368061337         NY  Bowling Green              NaN
#              368061605         NY            NaN         New York
#              368061607         NY            NaN         New York
#              368061657         NY            NaN         New York
#
#                        gnis:feature_id                      gnis:import_uuid  \
# element_type osmid
# node         368052081         2057419  57871b70-0100-4405-bb30-88b2e001a944
#              368061337         2057415                                   NaN
#              368061605         2091590                                   NaN
#              368061607         2091587                                   NaN
#              368061657         2080645  57871b70-0100-4405-bb30-88b2e001a944
#
#                                                           name  ... layer  \
# element_type osmid                                              ...
# node         368052081                  Fraunces Tavern Museum  ...   NaN
#              368061337  National Museum of the American Indian  ...   NaN
#              368061605               Yeshiva University Museum  ...   NaN
#              368061607                    Dahesh Museum of Art  ...   NaN
#              368061657                   Museum of African Art  ...   NaN
#
#                        name:cs name:it name:nl name:pt area ways type name:hi  \
# element_type osmid
# node         368052081     NaN     NaN     NaN     NaN  NaN  NaN  NaN     NaN
#              368061337     NaN     NaN     NaN     NaN  NaN  NaN  NaN     NaN
#              368061605     NaN     NaN     NaN     NaN  NaN  NaN  NaN     NaN
#              368061607     NaN     NaN     NaN     NaN  NaN  NaN  NaN     NaN
#              368061657     NaN     NaN     NaN     NaN  NaN  NaN  NaN     NaN
#
#                        name:de
# element_type osmid
# node         368052081     NaN
#              368061337     NaN
#              368061605     NaN
#              368061607     NaN
#              368061657     NaN
#
# [5 rows x 131 columns]

# %%
def popup_html(row):
    i = row
    museum_name=museums['name'].iloc[i]
    museum_access = museums['wheelchair'].iloc[i]

    left_col_color = "#3e95b5"
    right_col_color = "#f2f9ff"

    html = """
<!DOCTYPE html>
<html>
<table>
<tbody>
<tr>
<td style="background-color: """+ left_col_color +""";"><span style="color: #ffffff;">Museum Name </span></td>
<td style="width: 150px;background-color: """+ right_col_color +""";">"""+museum_name + """</td>
</tr>
<tr>
<td style="background-color: """+ left_col_color +""";"><span style="color: #ffffff;">Accesibility </span></td>
<td style="width: 150px;background-color: """+ right_col_color +""";">"""+format(museum_access) + """</td>
</tr>
</tbody>
</table></center>
</html>
"""
    return html

# %%
m2 = folium.Map([40.754932, -73.984016], zoom_start=10) # why I selected this particular location,
                                                        # what happens if I don't specify it?
locs=zip(museums_points.geometry.y,museums_points.geometry.x)
museum_names = museums_points.name
oids =range(0,len(museums_points))

for location,name,osid in zip(locs,museum_names,oids):


    html = popup_html(osid)

    popup = folium.Popup(folium.Html(html,script=True),max_width=500)
    folium.Marker(location=location, popup=popup).add_to(m2)
m2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_14d0f1d8fd0d9ec4518b8190c7db43b4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_14d0f1d8fd0d9ec4518b8190c7db43b4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_14d0f1d8fd0d9ec4518b8190c7db43b4 = L.map(
#                 &quot;map_14d0f1d8fd0d9ec4518b8190c7db43b4&quot;,
#                 {
#                     center: [40.754932, -73.984016],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3e9c8649cc7ecf342a3b49e23226d6d2 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_14d0f1d8fd0d9ec4518b8190c7db43b4);
#
#
#             var marker_2006f328c1a3c64368c9ec3638882ee5 = L.marker(
#                 [40.7033867, -74.0113536],
#                 {}
#             ).addTo(map_14d0f1d8fd0d9ec4518b8190c7db43b4);
#
#
#         var popup_2faf3fef33755e90d0b896427ab817a9 = L.popup({&quot;maxWidth&quot;: 500});
#
#
#
#                 var html_0056c87e03adfc6126f474c2be091209 = $(`&lt;div id=&quot;html_0056c87e03adfc6126f474c2be091209&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt; &lt;!DOCTYPE html&gt; &lt;html&gt; &lt;table&gt; &lt;tbody&gt; &lt;tr&gt; &lt;td style=&quot;background-color: #3e95b5;&quot;&gt;&lt;span style=&quot;color: #ffffff;&quot;&gt;Museum Name &lt;/span&gt;&lt;/td&gt; &lt;td style=&quot;width: 150px;background-color: #f2f9ff;&quot;&gt;Fraunces Tavern Museum&lt;/td&gt; &lt;/tr&gt; &lt;tr&gt; &lt;td style=&quot;background-color: #3e95b5;&quot;&gt;&lt;span style=&quot;color: #ffffff;&quot;&gt;Accesibility &lt;/span&gt;&lt;/td&gt; &lt;td style=&quot;width: 150px;background-color: #f2f9ff;&quot;&gt;yes&lt;/td&gt; &lt;/tr&gt; &lt;/tbody&gt; &lt;/table&gt;&lt;/center&gt; &lt;/html&gt; &lt;/div&gt;`)[0];
#                 popup_2faf3fef33755e90d0b896427ab817a9.setContent(html_0056c87e03adfc6126f474c2be091209);
#
#
#
#         marker_2006f328c1a3c64368c9ec3638882ee5.bindPopup(popup_2faf3fef33755e90d0b896427ab817a9)
#         ;
#
#
#
#
#             var marker_fe7fe33f9fc152e897f88b10687c4a6b = L.marker(
#                 [40.7040265, -74.0137472],
#                 {}
#             ).addTo(map_14d0f1d8fd0d9ec4518b8190c7db43b4);
#
#
#         var popup_4879a8569ce37b1d9372248dc8261e09 = L.popup({&quot;maxWidth&quot;: 500});
#
#
#
#                 var html_d3dd84d71317e0ff72b60b85637fe17f = $(`&lt;div id=&quot;html_d3dd84d71317e0ff72b60b85637fe17f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt; &lt;!DOCTYPE html&gt; &lt;html&gt; &lt;table&gt; &lt;tbody&gt; &lt;tr&gt; &lt;td style=&quot;background-color: #3e95b5;&quot;&gt;&lt;span style=&quot;color: #ffffff;&quot;&gt;Museum Name &lt;/span&gt;&lt;/td&gt; &lt;td style=&quot;width: 150px;background-color: #f2f9ff;&quot;&gt;National Museum of the American Indian&lt;/td&gt; &lt;/tr&gt; &lt;tr&gt; &lt;td style=&quot;background-color: #3e95b5;&quot;&gt;&lt;span style=&quot;color: #ffffff;&quot;&gt;Accesibility &lt;/span&gt;&lt;/td&gt; &lt;td style=&quot;width: 150px;background-color: #f2f9ff;&quot;&gt;yes&lt;/td&gt; &lt;/tr&gt; &lt;/tbody&gt; &lt;/table&gt;&lt;/center&gt; &lt;/html&gt; &lt;/div&gt;`)[0];
#                 popup_4879a8569ce37b1d9372248dc8261e09.setContent(html_d3dd84d71317e0ff72b60b85637fe17f);
#
#
#
#         marker_fe7fe33f9fc152e897f88b10687c4a6b.bindPopup(popup_4879a8569ce37b1d9372248dc8261e09)
#         ;
#
#
#
#
#             var marker_03683ef254621be5b5bdfb220f59a4eb = L.marker(
#                 [40.737978, -73.9938312],
#                 {}
#             ).addTo(map_14d0f1d8fd0d9ec4518b8190c7db43b4);
#
#
#         var popup_caecaee0ffadd663b75b09d4a685915a = L.popup({&quot;maxWidth&quot;: 500});
#
#
#
#                 var html_84f4155d44f0aade866c62cf13310c6e = $(`&lt;div id=&quot;html_84f4155d44f0aade866c62cf13310c6e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt; &lt;!DOCTYPE html&gt; &lt;html&gt; &lt;table&gt; &lt;tbody&gt; &lt;tr&gt; &lt;td style=&quot;background-color: #3e95b5;&quot;&gt;&lt;span style=&quot;color: #ffffff;&quot;&gt;Museum Name &lt;/span&gt;&lt;/td&gt; &lt;td style=&quot;width: 150px;background-color: #f2f9ff;&quot;&gt;Yeshiva University Museum&lt;/td&gt; &lt;/tr&gt; &lt;tr&gt; &lt;td style=&quot;background-color: #3e95b5;&quot;&gt;&lt;span style=&quot;color: #ffffff;&quot;&gt;Accesibility &lt;/span&gt;&lt;/td&gt; &lt;td style=&quot;width: 150px;background-color: #f2f9ff;&quot;&gt;nan&lt;/td&gt; &lt;/tr&gt; &lt;/tbody&gt; &lt;/table&gt;&lt;/center&gt; &lt;/html&gt; &lt;/div&gt;`)[0];
#                 popup_caecaee0ffadd663b75b09d4a685915a.setContent(html_84f4155d44f0aade866c62cf13310c6e);

# %% [markdown]
# This exercise adapted from Juan Nathaniel's "Working with Open StreetMap in Python article.https://levelup.gitconnected.com/working-with-openstreetmap-in-python-c49396d98ad4
#
# V2 is an extension of Sharone  Li's "Use HTML in Folium Maps : A Comprehensive Guide for Data Scientist" article.https://towardsdatascience.com/use-html-in-folium-maps-a-comprehensive-guide-for-data-scientists-3af10baf9190
